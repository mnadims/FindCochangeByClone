# %%
from IPython.display import clear_output
import os.path
from os import path

data_loc ="C:/temp/"
subject_systems=["brlcad", "camellia", "carol", "ctags", "freecol", "jabref", "jedit", "qmailadmin"]
revisions=["2-2115", "1-273", "1-1700", "1-774", "1000-2000", "1-1545", "3787-4001", "1-317"]
clone_types=["type1", "type2blind", "type3pattern", "type3token"]
query_split=500

# %%
sid=0
for ss in subject_systems:
    files_not_found=""    
    rev_range=revisions[sid].split('-')
    #print(sid, ss, rev_range[0], rev_range[1])
    for ctype in clone_types:
        query_str=""
        for rev in range(int(rev_range[0]), int(rev_range[1])):
            clear_output(wait=True)
            print("Working for :", ss, ctype, rev, "/", rev_range[1])
            clone_path=data_loc+"cloneworks_"+ss+"/"+ctype+"/revision-"+str(rev)
            if(path.exists(clone_path+".clones")== False):
                files_not_found+=clone_path+".clones\n"
                
            if(path.exists(clone_path+".files")==False):
                files_not_found+=clone_path+".files\n"
                
            clones=open(clone_path+".clones","r").read().strip().split('\n') 
            files=open(clone_path+".files","r").read().strip().split('\n') 
            list_files=[]
            for f in files:
                if(f[0]!='#'):
                    list_files.append(f.split()[1].replace("../subject_systems/brlcad/revision-2/", ""))
                    #print(f)

            #list_clones=[]
            num_pairs=0            
            for c in clones:
                if(c[0]!='#'):
                    if(num_pairs%query_split==0):
                        if(num_pairs>0):
                            query_str+=";\n\n"
                        query_str+="INSERT INTO `clones_cloneworks` (`version`, `ClonePair`, `clone_type`, `file_name`, `startline`, `endline`) VALUES \n"
                    elif(num_pairs>0):
                        query_str+=",\n"
            #         if(num_pairs>0):
            #             query_str+=",\n"
                    cpair=c.split(',')
                    query_str+="('"+str(rev)+"', '"+str(num_pairs)+"', '"+ctype+"', '"+list_files[int(cpair[0])]+"', '"+cpair[1]+"', '"+cpair[2]+"'),\n"
                    query_str+="('"+str(rev)+"', '"+str(num_pairs)+"', '"+ctype+"', '"+list_files[int(cpair[3])]+"', '"+cpair[4]+"', '"+cpair[5]+"')"
                    num_pairs+=1
            query_str+=";"
            
        with open(data_loc+ss+"_cloneworks_"+ctype+".sql", "w") as text_file:
                text_file.write(query_str)
            
    with open(data_loc+ss+"_not_found.txt", "w") as text_file:
            text_file.write(files_not_found)
    sid+=1
# Out:
# Working for : brlcad type1 1943 / 2115

# %%
for i in range(3787, 4002):
    print("source G:/jedit_cloneworks_type3pattern/revision"+str(i)+".sql")
print()
# Out:
# source G:/jedit_cloneworks_type3pattern/revision3787.sql
# source G:/jedit_cloneworks_type3pattern/revision3788.sql
# source G:/jedit_cloneworks_type3pattern/revision3789.sql
# source G:/jedit_cloneworks_type3pattern/revision3790.sql
# source G:/jedit_cloneworks_type3pattern/revision3791.sql
# source G:/jedit_cloneworks_type3pattern/revision3792.sql
# source G:/jedit_cloneworks_type3pattern/revision3793.sql
# source G:/jedit_cloneworks_type3pattern/revision3794.sql
# source G:/jedit_cloneworks_type3pattern/revision3795.sql
# source G:/jedit_cloneworks_type3pattern/revision3796.sql
# source G:/jedit_cloneworks_type3pattern/revision3797.sql
# source G:/jedit_cloneworks_type3pattern/revision3798.sql
# source G:/jedit_cloneworks_type3pattern/revision3799.sql
# source G:/jedit_cloneworks_type3pattern/revision3800.sql
# source G:/jedit_cloneworks_type3pattern/revision3801.sql
# source G:/jedit_cloneworks_type3pattern/revision3802.sql
# source G:/jedit_cloneworks_type3pattern/revision3803.sql
# source G:/jedit_cloneworks_type3pattern/revision3804.sql
# source G:/jedit_cloneworks_type3pattern/revision3805.sql
# source G:/jedit_cloneworks_type3pattern/revision3806.sql
# source G:/jedit_cloneworks_type3pattern/revision3807.sql
# source G:/jedit_cloneworks_type3pattern/revision3808.sql
# source G:/jedit_cloneworks_type3pattern/revision3809.sql
# source G:/jedit_cloneworks_type3pattern/revision3810.sql
# source G:/jedit_cloneworks_type3pattern/revision3811.sql
# source G:/jedit_cloneworks_type3pattern/revision3812.sql
# source G:/jedit_cloneworks_type3pattern/revision3813.sql
# source G:/jedit_cloneworks_type3pattern/revision3814.sql
# source G:/jedit_cloneworks_type3pattern/revision3815.sql
# source G:/jedit_cloneworks_type3pattern/revision3816.sql
# source G:/jedit_cloneworks_type3pattern/revision3817.sql
# source G:/jedit_cloneworks_type3pattern/revision3818.sql
# source G:/jedit_cloneworks_type3pattern/revision3819.sql
# source G:/jedit_cloneworks_type3pattern/revision3820.sql
# source G:/jedit_cloneworks_type3pattern/revision3821.sql
# source G:/jedit_cloneworks_type3pattern/revision3822.sql
# source G:/jedit_cloneworks_type3pattern/revision3823.sql
# source G:/jedit_cloneworks_type3pattern/revision3824.sql
# source G:/jedit_cloneworks_type3pattern/revision3825.sql
# source G:/jedit_cloneworks_type3pattern/revision3826.sql
# source G:/jedit_cloneworks_type3pattern/revision3827.sql
# source G:/jedit_cloneworks_type3pattern/revision3828.sql
# source G:/jedit_cloneworks_type3pattern/revision3829.sql
# source G:/jedit_cloneworks_type3pattern/revision3830.sql
# source G:/jedit_cloneworks_type3pattern/revision3831.sql
# source G:/jedit_cloneworks_type3pattern/revision3832.sql
# source G:/jedit_cloneworks_type3pattern/revision3833.sql
# source G:/jedit_cloneworks_type3pattern/revision3834.sql
# source G:/jedit_cloneworks_type3pattern/revision3835.sql
# source G:/jedit_cloneworks_type3pattern/revision3836.sql
# source G:/jedit_cloneworks_type3pattern/revision3837.sql
# source G:/jedit_cloneworks_type3pattern/revision3838.sql
# source G:/jedit_cloneworks_type3pattern/revision3839.sql
# source G:/jedit_cloneworks_type3pattern/revision3840.sql
# source G:/jedit_cloneworks_type3pattern/revision3841.sql
# source G:/jedit_cloneworks_type3pattern/revision3842.sql
# source G:/jedit_cloneworks_type3pattern/revision3843.sql
# source G:/jedit_cloneworks_type3pattern/revision3844.sql
# source G:/jedit_cloneworks_type3pattern/revision3845.sql
# source G:/jedit_cloneworks_type3pattern/revision3846.sql
# source G:/jedit_cloneworks_type3pattern/revision3847.sql
# source G:/jedit_cloneworks_type3pattern/revision3848.sql
# source G:/jedit_cloneworks_type3pattern/revision3849.sql
# source G:/jedit_cloneworks_type3pattern/revision3850.sql
# source G:/jedit_cloneworks_type3pattern/revision3851.sql
# source G:/jedit_cloneworks_type3pattern/revision3852.sql
# source G:/jedit_cloneworks_type3pattern/revision3853.sql
# source G:/jedit_cloneworks_type3pattern/revision3854.sql
# source G:/jedit_cloneworks_type3pattern/revision3855.sql
# source G:/jedit_cloneworks_type3pattern/revision3856.sql
# source G:/jedit_cloneworks_type3pattern/revision3857.sql
# source G:/jedit_cloneworks_type3pattern/revision3858.sql
# source G:/jedit_cloneworks_type3pattern/revision3859.sql
# source G:/jedit_cloneworks_type3pattern/revision3860.sql
# source G:/jedit_cloneworks_type3pattern/revision3861.sql
# source G:/jedit_cloneworks_type3pattern/revision3862.sql
# source G:/jedit_cloneworks_type3pattern/revision3863.sql
# source G:/jedit_cloneworks_type3pattern/revision3864.sql
# source G:/jedit_cloneworks_type3pattern/revision3865.sql
# source G:/jedit_cloneworks_type3pattern/revision3866.sql
# source G:/jedit_cloneworks_type3pattern/revision3867.sql
# source G:/jedit_cloneworks_type3pattern/revision3868.sql
# source G:/jedit_cloneworks_type3pattern/revision3869.sql
# source G:/jedit_cloneworks_type3pattern/revision3870.sql
# source G:/jedit_cloneworks_type3pattern/revision3871.sql
# source G:/jedit_cloneworks_type3pattern/revision3872.sql
# source G:/jedit_cloneworks_type3pattern/revision3873.sql
# source G:/jedit_cloneworks_type3pattern/revision3874.sql
# source G:/jedit_cloneworks_type3pattern/revision3875.sql
# source G:/jedit_cloneworks_type3pattern/revision3876.sql
# source G:/jedit_cloneworks_type3pattern/revision3877.sql
# source G:/jedit_cloneworks_type3pattern/revision3878.sql
# source G:/jedit_cloneworks_type3pattern/revision3879.sql
# source G:/jedit_cloneworks_type3pattern/revision3880.sql
# source G:/jedit_cloneworks_type3pattern/revision3881.sql
# source G:/jedit_cloneworks_type3pattern/revision3882.sql
# source G:/jedit_cloneworks_type3pattern/revision3883.sql
# source G:/jedit_cloneworks_type3pattern/revision3884.sql
# source G:/jedit_cloneworks_type3pattern/revision3885.sql
# source G:/jedit_cloneworks_type3pattern/revision3886.sql
# source G:/jedit_cloneworks_type3pattern/revision3887.sql
# source G:/jedit_cloneworks_type3pattern/revision3888.sql
# source G:/jedit_cloneworks_type3pattern/revision3889.sql
# source G:/jedit_cloneworks_type3pattern/revision3890.sql
# source G:/jedit_cloneworks_type3pattern/revision3891.sql
# source G:/jedit_cloneworks_type3pattern/revision3892.sql
# source G:/jedit_cloneworks_type3pattern/revision3893.sql
# source G:/jedit_cloneworks_type3pattern/revision3894.sql
# source G:/jedit_cloneworks_type3pattern/revision3895.sql
# source G:/jedit_cloneworks_type3pattern/revision3896.sql
# source G:/jedit_cloneworks_type3pattern/revision3897.sql
# source G:/jedit_cloneworks_type3pattern/revision3898.sql
# source G:/jedit_cloneworks_type3pattern/revision3899.sql
# source G:/jedit_cloneworks_type3pattern/revision3900.sql
# source G:/jedit_cloneworks_type3pattern/revision3901.sql
# source G:/jedit_cloneworks_type3pattern/revision3902.sql
# source G:/jedit_cloneworks_type3pattern/revision3903.sql
# source G:/jedit_cloneworks_type3pattern/revision3904.sql
# source G:/jedit_cloneworks_type3pattern/revision3905.sql
# source G:/jedit_cloneworks_type3pattern/revision3906.sql
# source G:/jedit_cloneworks_type3pattern/revision3907.sql
# source G:/jedit_cloneworks_type3pattern/revision3908.sql
# source G:/jedit_cloneworks_type3pattern/revision3909.sql
# source G:/jedit_cloneworks_type3pattern/revision3910.sql
# source G:/jedit_cloneworks_type3pattern/revision3911.sql
# source G:/jedit_cloneworks_type3pattern/revision3912.sql
# source G:/jedit_cloneworks_type3pattern/revision3913.sql
# source G:/jedit_cloneworks_type3pattern/revision3914.sql
# source G:/jedit_cloneworks_type3pattern/revision3915.sql
# source G:/jedit_cloneworks_type3pattern/revision3916.sql
# source G:/jedit_cloneworks_type3pattern/revision3917.sql
# source G:/jedit_cloneworks_type3pattern/revision3918.sql
# source G:/jedit_cloneworks_type3pattern/revision3919.sql
# source G:/jedit_cloneworks_type3pattern/revision3920.sql
# source G:/jedit_cloneworks_type3pattern/revision3921.sql
# source G:/jedit_cloneworks_type3pattern/revision3922.sql
# source G:/jedit_cloneworks_type3pattern/revision3923.sql
# source G:/jedit_cloneworks_type3pattern/revision3924.sql
# source G:/jedit_cloneworks_type3pattern/revision3925.sql
# source G:/jedit_cloneworks_type3pattern/revision3926.sql
# source G:/jedit_cloneworks_type3pattern/revision3927.sql
# source G:/jedit_cloneworks_type3pattern/revision3928.sql
# source G:/jedit_cloneworks_type3pattern/revision3929.sql
# source G:/jedit_cloneworks_type3pattern/revision3930.sql
# source G:/jedit_cloneworks_type3pattern/revision3931.sql
# source G:/jedit_cloneworks_type3pattern/revision3932.sql
# source G:/jedit_cloneworks_type3pattern/revision3933.sql
# source G:/jedit_cloneworks_type3pattern/revision3934.sql
# source G:/jedit_cloneworks_type3pattern/revision3935.sql
# source G:/jedit_cloneworks_type3pattern/revision3936.sql
# source G:/jedit_cloneworks_type3pattern/revision3937.sql
# source G:/jedit_cloneworks_type3pattern/revision3938.sql
# source G:/jedit_cloneworks_type3pattern/revision3939.sql
# source G:/jedit_cloneworks_type3pattern/revision3940.sql
# source G:/jedit_cloneworks_type3pattern/revision3941.sql
# source G:/jedit_cloneworks_type3pattern/revision3942.sql
# source G:/jedit_cloneworks_type3pattern/revision3943.sql
# source G:/jedit_cloneworks_type3pattern/revision3944.sql
# source G:/jedit_cloneworks_type3pattern/revision3945.sql
# source G:/jedit_cloneworks_type3pattern/revision3946.sql
# source G:/jedit_cloneworks_type3pattern/revision3947.sql
# source G:/jedit_cloneworks_type3pattern/revision3948.sql
# source G:/jedit_cloneworks_type3pattern/revision3949.sql
# source G:/jedit_cloneworks_type3pattern/revision3950.sql
# source G:/jedit_cloneworks_type3pattern/revision3951.sql
# source G:/jedit_cloneworks_type3pattern/revision3952.sql
# source G:/jedit_cloneworks_type3pattern/revision3953.sql
# source G:/jedit_cloneworks_type3pattern/revision3954.sql
# source G:/jedit_cloneworks_type3pattern/revision3955.sql
# source G:/jedit_cloneworks_type3pattern/revision3956.sql
# source G:/jedit_cloneworks_type3pattern/revision3957.sql
# source G:/jedit_cloneworks_type3pattern/revision3958.sql
# source G:/jedit_cloneworks_type3pattern/revision3959.sql
# source G:/jedit_cloneworks_type3pattern/revision3960.sql
# source G:/jedit_cloneworks_type3pattern/revision3961.sql
# source G:/jedit_cloneworks_type3pattern/revision3962.sql
# source G:/jedit_cloneworks_type3pattern/revision3963.sql
# source G:/jedit_cloneworks_type3pattern/revision3964.sql
# source G:/jedit_cloneworks_type3pattern/revision3965.sql
# source G:/jedit_cloneworks_type3pattern/revision3966.sql
# source G:/jedit_cloneworks_type3pattern/revision3967.sql
# source G:/jedit_cloneworks_type3pattern/revision3968.sql
# source G:/jedit_cloneworks_type3pattern/revision3969.sql
# source G:/jedit_cloneworks_type3pattern/revision3970.sql
# source G:/jedit_cloneworks_type3pattern/revision3971.sql
# source G:/jedit_cloneworks_type3pattern/revision3972.sql
# source G:/jedit_cloneworks_type3pattern/revision3973.sql
# source G:/jedit_cloneworks_type3pattern/revision3974.sql
# source G:/jedit_cloneworks_type3pattern/revision3975.sql
# source G:/jedit_cloneworks_type3pattern/revision3976.sql
# source G:/jedit_cloneworks_type3pattern/revision3977.sql
# source G:/jedit_cloneworks_type3pattern/revision3978.sql
# source G:/jedit_cloneworks_type3pattern/revision3979.sql
# source G:/jedit_cloneworks_type3pattern/revision3980.sql
# source G:/jedit_cloneworks_type3pattern/revision3981.sql
# source G:/jedit_cloneworks_type3pattern/revision3982.sql
# source G:/jedit_cloneworks_type3pattern/revision3983.sql
# source G:/jedit_cloneworks_type3pattern/revision3984.sql
# source G:/jedit_cloneworks_type3pattern/revision3985.sql
# source G:/jedit_cloneworks_type3pattern/revision3986.sql
# source G:/jedit_cloneworks_type3pattern/revision3987.sql
# source G:/jedit_cloneworks_type3pattern/revision3988.sql
# source G:/jedit_cloneworks_type3pattern/revision3989.sql
# source G:/jedit_cloneworks_type3pattern/revision3990.sql
# source G:/jedit_cloneworks_type3pattern/revision3991.sql
# source G:/jedit_cloneworks_type3pattern/revision3992.sql
# source G:/jedit_cloneworks_type3pattern/revision3993.sql
# source G:/jedit_cloneworks_type3pattern/revision3994.sql
# source G:/jedit_cloneworks_type3pattern/revision3995.sql
# source G:/jedit_cloneworks_type3pattern/revision3996.sql
# source G:/jedit_cloneworks_type3pattern/revision3997.sql
# source G:/jedit_cloneworks_type3pattern/revision3998.sql
# source G:/jedit_cloneworks_type3pattern/revision3999.sql
# source G:/jedit_cloneworks_type3pattern/revision4000.sql
# source G:/jedit_cloneworks_type3pattern/revision4001.sql
