# %%
from IPython.display import clear_output
import os.path
from os import path

data_loc ="C:/temp/"
subject_systems=["brlcad", "camellia", "carol", "ctags", "freecol", "jabref", "jedit", "qmailadmin"]
revisions=["2-2115", "1-273", "1-1700", "1-774", "1000-2000", "1-1545", "3787-4001", "1-317"]
clone_types=["type1", "type2blind", "type3pattern", "type3token"]
query_split=500

# %%
sid=0
for ss in subject_systems:
    files_not_found=""    
    rev_range=revisions[sid].split('-')
    #print(sid, ss, rev_range[0], rev_range[1])
    for ctype in clone_types:
        query_str=""
        for rev in range(int(rev_range[0]), int(rev_range[1])):
            clear_output(wait=True)
            print("Working for :", ss, ctype, rev, "/", rev_range[1])
            clone_path=data_loc+"cloneworks_"+ss+"/"+ctype+"/revision-"+str(rev)
            if(path.exists(clone_path+".clones")== False):
                files_not_found+=clone_path+".clones\n"
                
            if(path.exists(clone_path+".files")==False):
                files_not_found+=clone_path+".files\n"
                
            clones=open(clone_path+".clones","r").read().strip().split('\n') 
            files=open(clone_path+".files","r").read().strip().split('\n') 
            list_files=[]
            for f in files:
                if(f[0]!='#'):
                    list_files.append(f.split()[1].replace("../subject_systems/brlcad/revision-2/", ""))
                    #print(f)

            #list_clones=[]
            num_pairs=0            
            for c in clones:
                if(c[0]!='#'):
                    if(num_pairs%query_split==0):
                        if(num_pairs>0):
                            query_str+=";\n\n"
                        query_str+="INSERT INTO `clones_cloneworks` (`version`, `ClonePair`, `clone_type`, `file_name`, `startline`, `endline`) VALUES \n"
                    elif(num_pairs>0):
                        query_str+=",\n"
            #         if(num_pairs>0):
            #             query_str+=",\n"
                    cpair=c.split(',')
                    query_str+="('"+str(rev)+"', '"+str(num_pairs)+"', '"+ctype+"', '"+list_files[int(cpair[0])]+"', '"+cpair[1]+"', '"+cpair[2]+"'),\n"
                    query_str+="('"+str(rev)+"', '"+str(num_pairs)+"', '"+ctype+"', '"+list_files[int(cpair[3])]+"', '"+cpair[4]+"', '"+cpair[5]+"')"
                    num_pairs+=1
            query_str+=";"
            
        with open(data_loc+ss+"_cloneworks_"+ctype+".sql", "w") as text_file:
                text_file.write(query_str)
            
    with open(data_loc+ss+"_not_found.txt", "w") as text_file:
            text_file.write(files_not_found)
    sid+=1
# Out:
# Working for : brlcad type1 1943 / 2115

# %%
for i in range(2, 1546):
    print("source E:/temp/jabref_cloneworks_type3pattern/revision"+str(i)+".sql")
print()
# Out:
# source E:/temp/jabref_cloneworks_type3pattern/revision2.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision3.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision4.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision5.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision6.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision7.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision8.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision9.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision10.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision11.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision12.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision13.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision14.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision15.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision16.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision17.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision18.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision19.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision20.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision21.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision22.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision23.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision24.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision25.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision26.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision27.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision28.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision29.sql
# source E:/temp/jabref_cloneworks_type3pattern/revision30.sql
# source E:/temp/jabref_cloneworks_type3pattern/rev